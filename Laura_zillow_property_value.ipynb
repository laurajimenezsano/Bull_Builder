# %%
# Dependencies

import gmaps
import numpy as np
import pandas as pd
import requests
import time
from datetime import datetime
from scipy.stats import linregress
from matplotlib import pyplot as plt
from config import (gkey2)

# %%
#import datasets (each dataset represents a different number of bedrooms - 1,2,3,4, or 5+)
zillow_value_1 = pd.read_csv('Resources/zillow_value_1.csv')
zillow_value_2 = pd.read_csv('Resources/zillow_value_2.csv')
zillow_value_3 = pd.read_csv('Resources/zillow_value_3.csv')

# %%
# differentiating number of bedrooms within the dataset, given that it does not come with it
zillow_value_1['Bdrm'] = "1"
zillow_value_2['Bdrm'] = "2"
zillow_value_3['Bdrm'] = "3"
len(zillow_value_1)+len(zillow_value_2)+len(zillow_value_3)
# Out:
# 74047

# %%
# merging all datasets together to work out of one clean document
properties = pd.concat([zillow_value_1,zillow_value_2,zillow_value_3])
len(properties)
# Out:
# 74047

# %%
# filter for california properties only:
properties_ca = properties.loc[properties['State']=="CA"]
len(properties_ca)
# Out:
# 4544

# %%
# remove columns that have values prior to date 12/31/2013
properties_ca = properties_ca[['RegionName','RegionType','StateName','State','City','Metro','CountyName','1/31/14','2/28/21','3/31/21','Bdrm']]
properties_ca.head()
# Out:
#     RegionName RegionType StateName State           City  \
# 12       94109        Zip        CA    CA  San Francisco
# 19       90250        Zip        CA    CA      Hawthorne
# 37       94565        Zip        CA    CA      Pittsburg
# 41       90046        Zip        CA    CA    Los Angeles
# 83       94501        Zip        CA    CA        Alameda
#
#                              Metro            CountyName   1/31/14  2/28/21  \
# 12   San Francisco-Oakland-Hayward  San Francisco County  716780.0   824861
# 19  Los Angeles-Long Beach-Anaheim    Los Angeles County  382463.0   608374
# 37   San Francisco-Oakland-Hayward   Contra Costa County       NaN   192942
# 41  Los Angeles-Long Beach-Anaheim    Los Angeles County  452491.0   647755
# 83   San Francisco-Oakland-Hayward        Alameda County  348254.0   562250
#
#     3/31/21 Bdrm
# 12   820867    1
# 19   614481    1
# 37   189534    1
# 41   650469    1
# 83   566397    1

# %%
# dropping nas
properties_ca = properties_ca.dropna()
len(properties_ca)
# Out:
# 3923

# %%
# calculate annual growth rate since 2014
properties_ca['CAGR'] = ((properties_ca['3/31/21'] - properties_ca['1/31/14'])/properties_ca['1/31/14']*100)
properties_ca = pd.DataFrame(properties_ca)
properties_ca = properties_ca.sort_values(by='CAGR', ascending=True)
properties_ca = properties_ca.dropna()
len(properties_ca)
# Out:
# 3923

# %%
properties_ca = properties_ca.loc[properties_ca['CAGR']>0]
properties_ca
# Out:
#        RegionName RegionType StateName State             City  \
# 22990       94567        Zip        CA    CA      Pope Valley
# 1421        95762        Zip        CA    CA  El Dorado Hills
# 3824        92555        Zip        CA    CA    Moreno Valley
# 25349       95554        Zip        CA    CA       Myers Flat
# 3667        94549        Zip        CA    CA        Lafayette
# ...           ...        ...       ...   ...              ...
# 3577        95816        Zip        CA    CA       Sacramento
# 2106        90266        Zip        CA    CA  Manhattan Beach
# 1015        95828        Zip        CA    CA           Florin
# 9950        90211        Zip        CA    CA    Beverly Hills
# 1313        95822        Zip        CA    CA       Sacramento
#
#                                      Metro           CountyName    1/31/14  \
# 22990                                 Napa          Napa County   341561.0
# 1421   Sacramento--Roseville--Arden-Arcade     El Dorado County   347207.0
# 3824      Riverside-San Bernardino-Ontario     Riverside County   364672.0
# 25349                Eureka-Arcata-Fortuna      Humboldt County   412021.0
# 3667         San Francisco-Oakland-Hayward  Contra Costa County  1034925.0
# ...                                    ...                  ...        ...
# 3577   Sacramento--Roseville--Arden-Arcade    Sacramento County   179658.0
# 2106        Los Angeles-Long Beach-Anaheim   Los Angeles County   804901.0
# 1015   Sacramento--Roseville--Arden-Arcade    Sacramento County    94743.0
# 9950        Los Angeles-Long Beach-Anaheim   Los Angeles County   789562.0
# 1313   Sacramento--Roseville--Arden-Arcade    Sacramento County   115210.0
#
#        2/28/21  3/31/21 Bdrm        CAGR
# 22990   343077   343655    2    0.613068
# 1421    346318   353654    1    1.856817
# 3824    369914   372444    1    2.131230
# 25349   424761   422492    3    2.541375
# 3667   1073843  1063895    1    2.799237
# ...        ...      ...  ...         ...
# 3577    547554   551084    1  206.740585
# 2106   2540611  2511376    1  212.010545
# 1015    293825   301028    1  217.731125
# 9950   2575394  2551752    3  223.185766
# 1313    390018   398346    1  245.756445
#
# [3906 rows x 12 columns]

# %%
# creating lat and long columns for final run
properties_ca['Lat'] = ""
properties_ca['Lng'] = ""
properties_ca
# Out:
#        RegionName RegionType StateName State             City  \
# 22990       94567        Zip        CA    CA      Pope Valley
# 1421        95762        Zip        CA    CA  El Dorado Hills
# 3824        92555        Zip        CA    CA    Moreno Valley
# 25349       95554        Zip        CA    CA       Myers Flat
# 3667        94549        Zip        CA    CA        Lafayette
# ...           ...        ...       ...   ...              ...
# 3577        95816        Zip        CA    CA       Sacramento
# 2106        90266        Zip        CA    CA  Manhattan Beach
# 1015        95828        Zip        CA    CA           Florin
# 9950        90211        Zip        CA    CA    Beverly Hills
# 1313        95822        Zip        CA    CA       Sacramento
#
#                                      Metro           CountyName    1/31/14  \
# 22990                                 Napa          Napa County   341561.0
# 1421   Sacramento--Roseville--Arden-Arcade     El Dorado County   347207.0
# 3824      Riverside-San Bernardino-Ontario     Riverside County   364672.0
# 25349                Eureka-Arcata-Fortuna      Humboldt County   412021.0
# 3667         San Francisco-Oakland-Hayward  Contra Costa County  1034925.0
# ...                                    ...                  ...        ...
# 3577   Sacramento--Roseville--Arden-Arcade    Sacramento County   179658.0
# 2106        Los Angeles-Long Beach-Anaheim   Los Angeles County   804901.0
# 1015   Sacramento--Roseville--Arden-Arcade    Sacramento County    94743.0
# 9950        Los Angeles-Long Beach-Anaheim   Los Angeles County   789562.0
# 1313   Sacramento--Roseville--Arden-Arcade    Sacramento County   115210.0
#
#        2/28/21  3/31/21 Bdrm        CAGR Lat Lng
# 22990   343077   343655    2    0.613068
# 1421    346318   353654    1    1.856817
# 3824    369914   372444    1    2.131230
# 25349   424761   422492    3    2.541375
# 3667   1073843  1063895    1    2.799237
# ...        ...      ...  ...         ...  ..  ..
# 3577    547554   551084    1  206.740585
# 2106   2540611  2511376    1  212.010545
# 1015    293825   301028    1  217.731125
# 9950   2575394  2551752    3  223.185766
# 1313    390018   398346    1  245.756445
#
# [3906 rows x 14 columns]

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey2}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in properties_ca.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    zipcode = row['RegionName']

    # update address key value
    params['address'] = (zipcode)

    # make request
    cities_lat_lng = requests.get(base_url, params=params)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    # print(cities_lat_lng.url)
    
    # convert to json
    cities_lat_lng = cities_lat_lng.json()

    properties_ca.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    properties_ca.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# %%
properties_ca.head()
# Out:
#        RegionName RegionType StateName State             City  \
# 22990       94567        Zip        CA    CA      Pope Valley
# 1421        95762        Zip        CA    CA  El Dorado Hills
# 3824        92555        Zip        CA    CA    Moreno Valley
# 25349       95554        Zip        CA    CA       Myers Flat
# 3667        94549        Zip        CA    CA        Lafayette
#
#                                      Metro           CountyName    1/31/14  \
# 22990                                 Napa          Napa County   341561.0
# 1421   Sacramento--Roseville--Arden-Arcade     El Dorado County   347207.0
# 3824      Riverside-San Bernardino-Ontario     Riverside County   364672.0
# 25349                Eureka-Arcata-Fortuna      Humboldt County   412021.0
# 3667         San Francisco-Oakland-Hayward  Contra Costa County  1034925.0
#
#        2/28/21  3/31/21 Bdrm      CAGR Lat Lng
# 22990   343077   343655    2  0.613068
# 1421    346318   353654    1  1.856817
# 3824    369914   372444    1  2.131230
# 25349   424761   422492    3  2.541375
# 3667   1073843  1063895    1  2.799237

# %%
properties_ca.to_csv("Resources/clean_property_value.csv", index = False)

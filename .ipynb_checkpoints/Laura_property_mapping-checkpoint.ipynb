# %%
# Dependencies

import gmaps
import numpy as np
import pandas as pd
import requests
import time
from datetime import datetime
from scipy.stats import linregress
from matplotlib import pyplot as plt
from config_Laura import (gkey)

# %%
property_dataset = pd.read_csv('Resources_Laura/clean_property_value.csv')
property_dataset.head()
# Out:
#    RegionName RegionType StateName State             City  \
# 0       94567        Zip        CA    CA      Pope Valley
# 1       95762        Zip        CA    CA  El Dorado Hills
# 2       92555        Zip        CA    CA    Moreno Valley
# 3       95554        Zip        CA    CA       Myers Flat
# 4       94549        Zip        CA    CA        Lafayette
#
#                                  Metro           CountyName    1/31/14  \
# 0                                 Napa          Napa County   341561.0
# 1  Sacramento--Roseville--Arden-Arcade     El Dorado County   347207.0
# 2     Riverside-San Bernardino-Ontario     Riverside County   364672.0
# 3                Eureka-Arcata-Fortuna      Humboldt County   412021.0
# 4        San Francisco-Oakland-Hayward  Contra Costa County  1034925.0
#
#    2/28/21  3/31/21  Bdrm      CAGR  Lat  Lng
# 0   343077   343655     2  0.613068  NaN  NaN
# 1   346318   353654     1  1.856817  NaN  NaN
# 2   369914   372444     1  2.131230  NaN  NaN
# 3   424761   422492     3  2.541375  NaN  NaN
# 4  1073843  1063895     1  2.799237  NaN  NaN

# %%
property_dataset = property_dataset.sort_values(by='CAGR', ascending=False)

# %%
# after cleaning, create back a dataframe for each of the houses with specific bedroom markets in case we want to separate
one_bedr = property_dataset.loc[property_dataset['Bdrm']==1]
two_bedr = property_dataset.loc[property_dataset['Bdrm']==2]
three_bedr = property_dataset.loc[property_dataset['Bdrm']==3]

# %%
max(three_bedr['CAGR'])
# Out:
# 223.18576628561152

# %%
#CONFIGURE GMAPS
gmaps.configure(api_key=gkey)

# Store 'Lat' and 'Lng' into  locations 
locations = three_bedr[["Lat", "Lng"]].astype(float)

# humity to plot heat map
CAGR_percent = three_bedr["CAGR"].astype(float)

# %%
# location Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=CAGR_percent, 
                                 dissipating=False, max_intensity=230,
                                 point_radius = 0.1)

fig.add_layer(heat_layer)

fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-7-3fb749f0f91c> in <module>
#       2 fig = gmaps.figure()
#       3
# ----> 4 heat_layer = gmaps.heatmap_layer(locations, weights=CAGR_percent,
#       5                                  dissipating=False, max_intensity=230,
#       6                                  point_radius = 0.1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#    1075             for key, value in kwargs.items():
#    1076                 if self.has_trait(key):
# -> 1077                     setattr(self, key, value)
#    1078                 else:
#    1079                     # passthrough args that don't set traits to super
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     602             raise TraitError('The "%s" trait is read-only.' % self.name)
#     603         else:
# --> 604             self.set(obj, value)
#     605
#     606     def _validate(self, obj, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     576
#     577     def set(self, obj, value):
# --> 578         new_value = self._validate(obj, value)
#     579         try:
#     580             old_value = obj._trait_values[self.name]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     608             return value
#     609         if hasattr(self, 'validate'):
# --> 610             value = self.validate(obj, value)
#     611         if obj._cross_validation_lock is False:
#     612             value = self._cross_validate(obj, value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/geotraitlets.py in validate(self, obj, value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
# ---> 27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
#      29         return super(LocationArray, self).validate(obj, locations_as_list)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/geotraitlets.py in _validate_latitude(latitude)
#     304         )
#     305     if not (-90.0 <= latitude <= 90.0):
# --> 306         raise InvalidPointException(
#     307             '{} is not a valid latitude. '
#     308             'Latitudes must lie between -90 and 90.'.format(latitude)
#
# InvalidPointException: nan is not a valid latitude. Latitudes must lie between -90 and 90.

# %%
#identify top 20 cities by highest CAGR
one_bedr.head(5)
# Out:
#       RegionName RegionType StateName State             City  \
# 3905       95822        Zip        CA    CA       Sacramento
# 3903       95828        Zip        CA    CA           Florin
# 3902       90266        Zip        CA    CA  Manhattan Beach
# 3901       95816        Zip        CA    CA       Sacramento
# 3898       95818        Zip        CA    CA       Sacramento
#
#                                     Metro          CountyName   1/31/14  \
# 3905  Sacramento--Roseville--Arden-Arcade   Sacramento County  115210.0
# 3903  Sacramento--Roseville--Arden-Arcade   Sacramento County   94743.0
# 3902       Los Angeles-Long Beach-Anaheim  Los Angeles County  804901.0
# 3901  Sacramento--Roseville--Arden-Arcade   Sacramento County  179658.0
# 3898  Sacramento--Roseville--Arden-Arcade   Sacramento County  170088.0
#
#       2/28/21  3/31/21  Bdrm        CAGR        Lat         Lng
# 3905   390018   398346     1  245.756445  38.512871 -121.497029
# 3903   293825   301028     1  217.731125  38.492988 -121.388467
# 3902  2540611  2511376     1  212.010545  33.890837 -118.398784
# 3901   547554   551084     1  206.740585  38.580018 -121.462758
# 3898   492207   500003     1  193.967240  38.560306 -121.497029

# %%
two_bedr.head(5)
# Out:
#       RegionName RegionType StateName State             City  \
# 3896       90266        Zip        CA    CA  Manhattan Beach
# 3893       95206        Zip        CA    CA         Stockton
# 3892       95205        Zip        CA    CA         Stockton
# 3891       90402        Zip        CA    CA     Santa Monica
# 3888       90021        Zip        CA    CA      Los Angeles
#
#                                Metro          CountyName   1/31/14  2/28/21  \
# 3896  Los Angeles-Long Beach-Anaheim  Los Angeles County  684856.0  2005789
# 3893                   Stockton-Lodi  San Joaquin County   89344.0   249062
# 3892                   Stockton-Lodi  San Joaquin County   90785.0   248692
# 3891  Los Angeles-Long Beach-Anaheim  Los Angeles County  897633.0  2508685
# 3888  Los Angeles-Long Beach-Anaheim  Los Angeles County  322393.0   870578
#
#       3/31/21  Bdrm        CAGR        Lat         Lng
# 3896  1993710     2  191.113752  33.890837 -118.398784
# 3893   254093     2  184.398505  37.900921 -121.422761
# 3892   253963     2  179.741147  37.964259 -121.256914
# 3891  2484871     2  176.824827  34.035282 -118.506833
# 3888   878312     2  172.435196  34.030926 -118.238043

# %%
three_bedr.head(5)
# Out:
#       RegionName RegionType StateName State             City  \
# 3904       90211        Zip        CA    CA    Beverly Hills
# 3900       91108        Zip        CA    CA       San Marino
# 3899       90266        Zip        CA    CA  Manhattan Beach
# 3895       90212        Zip        CA    CA    Beverly Hills
# 3894       90027        Zip        CA    CA      Los Angeles
#
#                                Metro          CountyName   1/31/14  2/28/21  \
# 3904  Los Angeles-Long Beach-Anaheim  Los Angeles County  789562.0  2575394
# 3900  Los Angeles-Long Beach-Anaheim  Los Angeles County  609176.0  1810066
# 3899  Los Angeles-Long Beach-Anaheim  Los Angeles County  802363.0  2372472
# 3895  Los Angeles-Long Beach-Anaheim  Los Angeles County  994511.0  2904606
# 3894  Los Angeles-Long Beach-Anaheim  Los Angeles County  586644.0  1677238
#
#       3/31/21  Bdrm        CAGR        Lat         Lng
# 3904  2551752     3  223.185766  34.066107 -118.384178
# 3900  1820804     3  198.896214  34.124792 -118.118120
# 3899  2362929     3  194.496257  33.890837 -118.398784
# 3895  2876834     3  189.271210  34.061711 -118.401705
# 3894  1693712     3  188.712064  34.122054 -118.293589

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

one_bedr_zip = one_bedr['RegionName'].to_list()

rank_one = []
new_zipcode = []

for zipcode in one_bedr_zip:
    rank_one.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
one_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_one':rank_one})

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

two_bedr_zip = two_bedr['RegionName'].to_list()
three_bedr_zip = three_bedr['RegionName'].to_list()

rank_two = []
new_zipcode = []

for zipcode in two_bedr_zip:
    rank_two.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
two_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_two':rank_two})

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

three_bedr_zip = three_bedr['RegionName'].to_list()

rank_three = []
new_zipcode = []

for zipcode in three_bedr_zip:
    rank_three.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
three_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_three':rank_three})

# %%
ranking = pd.merge(one_bedr_df, two_bedr_df, on="RegionName")
ranking = pd.merge(ranking, three_bedr_df, on="RegionName")
ranking = ranking.dropna()
ranking.head()
# Out:
#    RegionName  rank_one  rank_two  rank_three
# 0       95822         1        24         331
# 1       95828         2       117         240
# 2       90266         3         1           3
# 3       95816         4       139           9
# 4       95818         5       408           8

# %%
#add rankings together, to see which zipcode has best CAGR across all home types

sum_column = ranking["rank_one"] + ranking["rank_two"] + ranking["rank_three"]
ranking["rank_sum"] = sum_column
ranking = ranking.sort_values(by='rank_sum', ascending=True)
ranking.head(10)
# Out:
#     RegionName  rank_one  rank_two  rank_three  rank_sum
# 2        90266         3         1           3         7
# 9        92252        10        16          47        73
# 12       90254        13        44          28        85
# 75       95205        78         3          13        94
# 41       94621        43        52          25       120
# 50       95215        52        32          41       125
# 6        92007         7        42          81       130
# 19       95824        20        29          94       143
# 71       95351        74        13          59       146
# 3        95816         4       139           9       152

# %%
most_favorable = ranking.head(10)
most_favorable = most_favorable['RegionName'].to_list()

most_favorable = property_dataset[property_dataset['RegionName'].isin([90266, 92252,90254,95205,94621,95215,92007,95824,95351,95816])]

# %%
most_favorable
# Out:
#       RegionName RegionType StateName State             City  \
# 3902       90266        Zip        CA    CA  Manhattan Beach
# 3901       95816        Zip        CA    CA       Sacramento
# 3899       90266        Zip        CA    CA  Manhattan Beach
# 3896       90266        Zip        CA    CA  Manhattan Beach
# 3892       95205        Zip        CA    CA         Stockton
# 3890       92007        Zip        CA    CA        Encinitas
# 3880       92252        Zip        CA    CA      Joshua Tree
# 3875       95816        Zip        CA    CA       Sacramento
# 3871       95351        Zip        CA    CA          Modesto
# 3868       90254        Zip        CA    CA    Hermosa Beach
# 3861       95205        Zip        CA    CA         Stockton
# 3858       92252        Zip        CA    CA      Joshua Tree
# 3856       95824        Zip        CA    CA       Sacramento
# 3837       95824        Zip        CA    CA       Sacramento
# 3830       95215        Zip        CA    CA     Garden Acres
# 3804       92007        Zip        CA    CA        Encinitas
# 3801       90254        Zip        CA    CA    Hermosa Beach
# 3798       94621        Zip        CA    CA          Oakland
# 3792       90254        Zip        CA    CA    Hermosa Beach
# 3784       94621        Zip        CA    CA          Oakland
# 3764       94621        Zip        CA    CA          Oakland
# 3738       95215        Zip        CA    CA     Garden Acres
# 3733       95215        Zip        CA    CA     Garden Acres
# 3705       92252        Zip        CA    CA      Joshua Tree
# 3673       95351        Zip        CA    CA          Modesto
# 3657       95205        Zip        CA    CA         Stockton
# 3640       95351        Zip        CA    CA          Modesto
# 3601       95816        Zip        CA    CA       Sacramento
# 3570       92007        Zip        CA    CA        Encinitas
# 3514       95824        Zip        CA    CA       Sacramento
#
#                                     Metro             CountyName   1/31/14  \
# 3902       Los Angeles-Long Beach-Anaheim     Los Angeles County  804901.0
# 3901  Sacramento--Roseville--Arden-Arcade      Sacramento County  179658.0
# 3899       Los Angeles-Long Beach-Anaheim     Los Angeles County  802363.0
# 3896       Los Angeles-Long Beach-Anaheim     Los Angeles County  684856.0
# 3892                        Stockton-Lodi     San Joaquin County   90785.0
# 3890                   San Diego-Carlsbad       San Diego County  499139.0
# 3880     Riverside-San Bernardino-Ontario  San Bernardino County   96129.0
# 3875  Sacramento--Roseville--Arden-Arcade      Sacramento County  299029.0
# 3871                              Modesto      Stanislaus County  100196.0
# 3868       Los Angeles-Long Beach-Anaheim     Los Angeles County  465994.0
# 3861                        Stockton-Lodi     San Joaquin County  115753.0
# 3858     Riverside-San Bernardino-Ontario  San Bernardino County  116269.0
# 3856  Sacramento--Roseville--Arden-Arcade      Sacramento County   98086.0
# 3837  Sacramento--Roseville--Arden-Arcade      Sacramento County  119347.0
# 3830                        Stockton-Lodi     San Joaquin County  116800.0
# 3804                   San Diego-Carlsbad       San Diego County  424538.0
# 3801       Los Angeles-Long Beach-Anaheim     Los Angeles County  651939.0
# 3798        San Francisco-Oakland-Hayward         Alameda County  240409.0
# 3792       Los Angeles-Long Beach-Anaheim     Los Angeles County  817915.0
# 3784        San Francisco-Oakland-Hayward         Alameda County  223933.0
# 3764        San Francisco-Oakland-Hayward         Alameda County  206841.0
# 3738                        Stockton-Lodi     San Joaquin County  159637.0
# 3733                        Stockton-Lodi     San Joaquin County  109512.0
# 3705     Riverside-San Bernardino-Ontario  San Bernardino County  145787.0
# 3673                              Modesto      Stanislaus County  109707.0
# 3657                        Stockton-Lodi     San Joaquin County   93168.0
# 3640                              Modesto      Stanislaus County  141317.0
# 3601  Sacramento--Roseville--Arden-Arcade      Sacramento County  291775.0
# 3570                   San Diego-Carlsbad       San Diego County  701864.0
# 3514  Sacramento--Roseville--Arden-Arcade      Sacramento County  158266.0
#
#       2/28/21  3/31/21  Bdrm        CAGR        Lat         Lng
# 3902  2540611  2511376     1  212.010545  33.890837 -118.398784
# 3901   547554   551084     1  206.740585  38.580018 -121.462758
# 3899  2372472  2362929     3  194.496257  33.890837 -118.398784
# 3896  2005789  1993710     2  191.113752  33.890837 -118.398784
# 3892   248692   253963     2  179.741147  37.964259 -121.256914
# 3890  1373708  1371843     1  174.841878  33.017025 -117.273490
# 3880   247008   255545     1  165.835492  34.193766 -116.254086
# 3875   767138   771831     3  158.112424  38.580018 -121.462758
# 3871   251848   257090     2  156.587089  37.618393 -120.993368
# 3868  1163724  1170339     1  151.148942  33.860069 -118.398784
# 3861   283172   287941     3  148.754676  37.964259 -121.256914
# 3858   279791   287877     2  147.595662  34.193766 -116.254086
# 3856   234815   242261     1  146.988357  38.517011 -121.451331
# 3837   281059   285951     2  139.596303  38.517011 -121.451331
# 3830   272366   278533     2  138.470034  37.943493 -121.148128
# 3804   981892   983883     2  131.753812  33.017025 -117.273490
# 3801  1496807  1508644     2  131.408767  33.860069 -118.398784
# 3798   547186   555056     3  130.879876  37.734744 -122.214332
# 3792  1872491  1880546     3  129.919490  38.517011 -121.451331
# 3784   504182   509843     2  127.676582  37.734744 -122.214332
# 3764   459669   464491     1  124.564279  37.734744 -122.214332
# 3738   343911   350248     3  119.402770  37.943493 -121.148128
# 3733   236269   239553     1  118.745891  37.943493 -121.148128
# 3705   304513   313996     3  115.379972  34.193766 -116.254086
# 3673   229014   233284     1  112.642767  37.618393 -120.993368
# 3657   193530   196880     1  111.317190  37.964259 -121.256914
# 3640   292936   296738     3  109.980399  37.618393 -120.993368
# 3601   595273   603026     2  106.675006  38.580018 -121.462758
# 3570  1417585  1429899     3  103.728785  33.017025 -117.273490
# 3514   311619   315739     3   99.498945  38.517011 -121.451331

# %%
# Convert nearest hotel to list and filter for null values (where hotel was not found within range)

cities = most_favorable["City"].tolist()

marker_locations = most_favorable[['Lat', 'Lng']]

# %%
# Create a marker_layer using the poverty list to fill the info box and combine both maps together
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations,
    info_box_content=[f"Profitable: {cities}" for city in cities])
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

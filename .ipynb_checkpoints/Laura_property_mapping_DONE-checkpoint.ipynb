# %%
# Dependencies

import gmaps
import numpy as np
import pandas as pd
import requests
import time
from datetime import datetime
from scipy.stats import linregress
from matplotlib import pyplot as plt
from config_Laura import (gkey)

# %%
property_dataset = pd.read_csv('Resources_Laura/clean_property_value.csv')
len(property_dataset)
# Out:
# 3923

# %%
property_data_neg = property_dataset.loc[property_dataset['% Change']<3]
property_data_neg

# negproperty_dataset['% Change']<0:
# Out:
#     RegionName RegionType StateName State             City  \
# 0        95412        Zip        CA    CA        Annapolis
# 1        95412        Zip        CA    CA        Annapolis
# 3        95017        Zip        CA    CA        Davenport
# 6        94020        Zip        CA    CA         La Honda
# 8        94060        Zip        CA    CA        Pescadero
# 10       93110        Zip        CA    CA    Santa Barbara
# 13       93920        Zip        CA    CA          Big Sur
# 14       95559        Zip        CA    CA       Myers Flat
# 15       96142        Zip        CA    CA           Tahoma
# 18       93224        Zip        CA    CA          Fellows
# 19       95033        Zip        CA    CA  Lexington Hills
# 22       91980        Zip        CA    CA           Tecate
# 24       95488        Zip        CA    CA         Westport
# 26       95553        Zip        CA    CA       Myers Flat
# 27       95421        Zip        CA    CA         Cazadero
# 30       95542        Zip        CA    CA      Garberville
# 32       94922        Zip        CA    CA       Occidental
# 34       94567        Zip        CA    CA      Pope Valley
# 35       95762        Zip        CA    CA  El Dorado Hills
# 38       92555        Zip        CA    CA    Moreno Valley
# 41       95554        Zip        CA    CA       Myers Flat
# 42       94549        Zip        CA    CA        Lafayette
#
#                                   Metro            CountyName    1/31/14  \
# 0                            Santa Rosa         Sonoma County   721046.0
# 1                            Santa Rosa         Sonoma County   730825.0
# 3                Santa Cruz-Watsonville     Santa Cruz County   789701.0
# 6         San Francisco-Oakland-Hayward      San Mateo County  1047622.0
# 8         San Francisco-Oakland-Hayward      San Mateo County  1425555.0
# 10            Santa Maria-Santa Barbara  Santa Barbara County   589390.0
# 13                              Salinas       Monterey County  2695050.0
# 14                Eureka-Arcata-Fortuna       Humboldt County   330723.0
# 15  Sacramento--Roseville--Arden-Arcade      El Dorado County   476696.0
# 18                          Bakersfield           Kern County   152653.0
# 19       San Jose-Sunnyvale-Santa Clara    Santa Clara County   930453.0
# 22                   San Diego-Carlsbad      San Diego County   476754.0
# 24                                Ukiah      Mendocino County   491183.0
# 26                Eureka-Arcata-Fortuna       Humboldt County   478994.0
# 27                           Santa Rosa         Sonoma County   806680.0
# 30                Eureka-Arcata-Fortuna       Humboldt County   460321.0
# 32                           Santa Rosa         Sonoma County   883024.0
# 34                                 Napa           Napa County   341561.0
# 35  Sacramento--Roseville--Arden-Arcade      El Dorado County   347207.0
# 38     Riverside-San Bernardino-Ontario      Riverside County   364672.0
# 41                Eureka-Arcata-Fortuna       Humboldt County   412021.0
# 42        San Francisco-Oakland-Hayward   Contra Costa County  1034925.0
#
#     2/28/21  3/31/21  Bdrm   % Change        Lat         Lng
# 0    526204   520369     1 -27.831373  38.713892 -123.326167
# 1    653418   645435     2 -11.684056  38.713892 -123.326167
# 3    609039   612187     1 -22.478634  37.091858 -122.231354
# 6    848184   854623     2 -18.422580  37.291115 -122.208658
# 8   1185489  1185573     2 -16.834286  37.205116 -122.333426
# 10   508970   511314     1 -13.246916  34.508431 -119.731021
# 13  2419143  2379601     3 -11.704755  36.051496 -121.514162
# 14   298207   298834     2  -9.642208  40.196618 -123.800432
# 15   436435   437163     1  -8.293126  39.050130 -120.141609
# 18   143991   144003     3  -5.666446  35.203105 -119.580360
# 19   902967   894681     1  -3.844579  37.161104 -121.970062
# 22   470555   458761     2  -3.774064  32.584138 -116.614062
# 24   474109   472722     3  -3.758477  39.716228 -123.774120
# 26   478975   462099     3  -3.527184  40.266125 -123.927809
# 27   793301   793572     3  -1.624932  38.607353 -123.191372
# 30   456241   455571     3  -1.031889  40.089305 -123.703883
# 32   886027   878710     2  -0.488548  38.341289 -122.949401
# 34   343077   343655     2   0.613068  38.684420 -122.469369
# 35   346318   353654     1   1.856817  38.657591 -121.056443
# 38   369914   372444     1   2.131230  33.920685 -117.114710
# 41   424761   422492     3   2.541375  40.267691 -123.782328
# 42  1073843  1063895     1   2.799237  37.892946 -122.117826

# %%
#sorting by % change and removing those that are negative, since we do not want to see those in the heatmap.
property_dataset = property_dataset.sort_values(by='% Change', ascending=False)
property_dataset = property_dataset.loc[property_dataset['% Change']>0]

# %%
# after cleaning, create back a dataframe for each of the houses with specific bedroom markets in case we want to separate
one_bedr = property_dataset.loc[property_dataset['Bdrm']==1]
two_bedr = property_dataset.loc[property_dataset['Bdrm']==2]
three_bedr = property_dataset.loc[property_dataset['Bdrm']==3]

# %%
three_bedr.head(10)
# Out:
#       RegionName RegionType StateName State             City  \
# 3109       90211        Zip        CA    CA    Beverly Hills
# 3919       91108        Zip        CA    CA       San Marino
# 3921       90266        Zip        CA    CA  Manhattan Beach
# 2743       90212        Zip        CA    CA    Beverly Hills
# 3581       90027        Zip        CA    CA      Los Angeles
# 3917       95817        Zip        CA    CA       Sacramento
# 3248       94610        Zip        CA    CA          Oakland
# 3472       95818        Zip        CA    CA       Sacramento
# 3875       95816        Zip        CA    CA       Sacramento
# 3538       95202        Zip        CA    CA         Stockton
#
#                                     Metro          CountyName   1/31/14  \
# 3109       Los Angeles-Long Beach-Anaheim  Los Angeles County  789562.0
# 3919       Los Angeles-Long Beach-Anaheim  Los Angeles County  609176.0
# 3921       Los Angeles-Long Beach-Anaheim  Los Angeles County  802363.0
# 2743       Los Angeles-Long Beach-Anaheim  Los Angeles County  994511.0
# 3581       Los Angeles-Long Beach-Anaheim  Los Angeles County  586644.0
# 3917  Sacramento--Roseville--Arden-Arcade   Sacramento County  183057.0
# 3248        San Francisco-Oakland-Hayward      Alameda County  669975.0
# 3472  Sacramento--Roseville--Arden-Arcade   Sacramento County  297671.0
# 3875  Sacramento--Roseville--Arden-Arcade   Sacramento County  299029.0
# 3538                        Stockton-Lodi  San Joaquin County  123896.0
#
#       2/28/21  3/31/21  Bdrm    % Change        Lat         Lng
# 3109  2575394  2551752     3  223.185766  34.066107 -118.384178
# 3919  1810066  1820804     3  198.896214  34.124792 -118.118120
# 3921  2372472  2362929     3  194.496257  33.890837 -118.398784
# 2743  2904606  2876834     3  189.271210  34.061711 -118.401705
# 3581  1677238  1693712     3  188.712064  34.122054 -118.293589
# 3917   492476   499768     3  173.012231  38.550043 -121.459901
# 3248  1767567  1799871     3  168.647487  37.810448 -122.239864
# 3472   764333   770494     3  158.840801  38.560306 -121.497029
# 3875   767138   771831     3  158.112424  38.580018 -121.462758
# 3538   312822   318038     3  156.697553  37.957384 -121.288386

# %%
min(one_bedr['% Change'])
# Out:
# 1.8568174028749418

# %%
#CONFIGURE GMAPS
gmaps.configure(api_key=gkey)

# Store 'Lat' and 'Lng' into  locations 
locations = one_bedr[["Lat", "Lng"]].astype(float)

# humity to plot heat map
CAGR_percent = one_bedr["% Change"].astype(float)

# %%
# location Heatmap layer (change depending on which one you'd like to plot)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=CAGR_percent, 
                                 dissipating=False, max_intensity=180,
                                 point_radius = 0.1)
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

one_bedr_zip = one_bedr['RegionName'].to_list()

rank_one = []
new_zipcode = []

for zipcode in one_bedr_zip:
    rank_one.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
one_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_one':rank_one})

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

two_bedr_zip = two_bedr['RegionName'].to_list()

rank_two = []
new_zipcode = []

for zipcode in two_bedr_zip:
    rank_two.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
two_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_two':rank_two})

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

three_bedr_zip = three_bedr['RegionName'].to_list()

rank_three = []
new_zipcode = []

for zipcode in three_bedr_zip:
    rank_three.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
three_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_three':rank_three})

# %%
# final summary table to rank the zip codes with the highest increases in property values. We chose rank because if we do an average of % change of al three types, one high increase may impact the overall average.
ranking = pd.merge(one_bedr_df, two_bedr_df, on="RegionName")
ranking = pd.merge(ranking, three_bedr_df, on="RegionName")
ranking = ranking.dropna()
ranking.head()
# Out:
#    RegionName  rank_one  rank_two  rank_three
# 0       95822         1        24         331
# 1       95828         2       117         240
# 2       90266         3         1           3
# 3       95816         4       139           9
# 4       95818         5       408           8

# %%
#add rankings together, to see which zipcode has best % increase across all home types

sum_column = ranking["rank_one"] + ranking["rank_two"] + ranking["rank_three"]
ranking["rank_sum"] = sum_column
ranking = ranking.sort_values(by='rank_sum', ascending=True)
ranking.head(10)
# Out:
#     RegionName  rank_one  rank_two  rank_three  rank_sum
# 2        90266         3         1           3         7
# 9        92252        10        16          47        73
# 12       90254        13        44          28        85
# 75       95205        78         3          13        94
# 41       94621        43        52          25       120
# 50       95215        52        32          41       125
# 6        92007         7        42          81       130
# 19       95824        20        29          94       143
# 71       95351        74        13          59       146
# 3        95816         4       139           9       152

# %%
#find city that has best property increase value in all 3 house types
winner_value = int(ranking['RegionName'].head(1))
finder_value = property_dataset.loc[property_dataset['RegionName']==winner_value]
answer = finder_value['City']
answer = answer.drop_duplicates()


print('The zipcode with best ranking in terms of property value increase for one, two and three bedrooms is Sacramento''')
# Out:
# The zipcode with best ranking in terms of property value increase for one, two and three bedrooms is Sacramento

# %%
# dataset to plot the top 10 cities with highest ranking property increase for all 3 bedrooms
most_favorable = ranking.head(10)
most_favorable = most_favorable['RegionName'].to_list()
most_favorable_group = property_dataset.loc[property_dataset['RegionName'].isin(most_favorable)]
most_favorable_group
# Out:
#       RegionName RegionType StateName State             City  \
# 3922       90266        Zip        CA    CA  Manhattan Beach
# 3876       95816        Zip        CA    CA       Sacramento
# 3921       90266        Zip        CA    CA  Manhattan Beach
# 3920       90266        Zip        CA    CA  Manhattan Beach
# 3895       95205        Zip        CA    CA         Stockton
# 3861       92007        Zip        CA    CA        Encinitas
# 3900       92252        Zip        CA    CA      Joshua Tree
# 3875       95816        Zip        CA    CA       Sacramento
# 3891       95351        Zip        CA    CA          Modesto
# 3912       90254        Zip        CA    CA    Hermosa Beach
# 3894       95205        Zip        CA    CA         Stockton
# 3899       92252        Zip        CA    CA      Joshua Tree
# 3836       95824        Zip        CA    CA       Sacramento
# 3835       95824        Zip        CA    CA       Sacramento
# 3904       95215        Zip        CA    CA     Garden Acres
# 3860       92007        Zip        CA    CA        Encinitas
# 3911       90254        Zip        CA    CA    Hermosa Beach
# 3909       94621        Zip        CA    CA          Oakland
# 3910       90254        Zip        CA    CA    Hermosa Beach
# 3908       94621        Zip        CA    CA          Oakland
# 3907       94621        Zip        CA    CA          Oakland
# 3903       95215        Zip        CA    CA     Garden Acres
# 3902       95215        Zip        CA    CA     Garden Acres
# 3898       92252        Zip        CA    CA      Joshua Tree
# 3890       95351        Zip        CA    CA          Modesto
# 3893       95205        Zip        CA    CA         Stockton
# 3889       95351        Zip        CA    CA          Modesto
# 3874       95816        Zip        CA    CA       Sacramento
# 3859       92007        Zip        CA    CA        Encinitas
# 3834       95824        Zip        CA    CA       Sacramento
#
#                                     Metro             CountyName   1/31/14  \
# 3922       Los Angeles-Long Beach-Anaheim     Los Angeles County  804901.0
# 3876  Sacramento--Roseville--Arden-Arcade      Sacramento County  179658.0
# 3921       Los Angeles-Long Beach-Anaheim     Los Angeles County  802363.0
# 3920       Los Angeles-Long Beach-Anaheim     Los Angeles County  684856.0
# 3895                        Stockton-Lodi     San Joaquin County   90785.0
# 3861                   San Diego-Carlsbad       San Diego County  499139.0
# 3900     Riverside-San Bernardino-Ontario  San Bernardino County   96129.0
# 3875  Sacramento--Roseville--Arden-Arcade      Sacramento County  299029.0
# 3891                              Modesto      Stanislaus County  100196.0
# 3912       Los Angeles-Long Beach-Anaheim     Los Angeles County  465994.0
# 3894                        Stockton-Lodi     San Joaquin County  115753.0
# 3899     Riverside-San Bernardino-Ontario  San Bernardino County  116269.0
# 3836  Sacramento--Roseville--Arden-Arcade      Sacramento County   98086.0
# 3835  Sacramento--Roseville--Arden-Arcade      Sacramento County  119347.0
# 3904                        Stockton-Lodi     San Joaquin County  116800.0
# 3860                   San Diego-Carlsbad       San Diego County  424538.0
# 3911       Los Angeles-Long Beach-Anaheim     Los Angeles County  651939.0
# 3909        San Francisco-Oakland-Hayward         Alameda County  240409.0
# 3910       Los Angeles-Long Beach-Anaheim     Los Angeles County  817915.0
# 3908        San Francisco-Oakland-Hayward         Alameda County  223933.0
# 3907        San Francisco-Oakland-Hayward         Alameda County  206841.0
# 3903                        Stockton-Lodi     San Joaquin County  159637.0
# 3902                        Stockton-Lodi     San Joaquin County  109512.0
# 3898     Riverside-San Bernardino-Ontario  San Bernardino County  145787.0
# 3890                              Modesto      Stanislaus County  109707.0
# 3893                        Stockton-Lodi     San Joaquin County   93168.0
# 3889                              Modesto      Stanislaus County  141317.0
# 3874  Sacramento--Roseville--Arden-Arcade      Sacramento County  291775.0
# 3859                   San Diego-Carlsbad       San Diego County  701864.0
# 3834  Sacramento--Roseville--Arden-Arcade      Sacramento County  158266.0
#
#       2/28/21  3/31/21  Bdrm    % Change        Lat         Lng
# 3922  2540611  2511376     1  212.010545  33.890837 -118.398784
# 3876   547554   551084     1  206.740585  38.580018 -121.462758
# 3921  2372472  2362929     3  194.496257  33.890837 -118.398784
# 3920  2005789  1993710     2  191.113752  33.890837 -118.398784
# 3895   248692   253963     2  179.741147  37.964259 -121.256914
# 3861  1373708  1371843     1  174.841878  33.017025 -117.273490
# 3900   247008   255545     1  165.835492  34.193766 -116.254086
# 3875   767138   771831     3  158.112424  38.580018 -121.462758
# 3891   251848   257090     2  156.587089  37.618393 -120.993368
# 3912  1163724  1170339     1  151.148942  33.860069 -118.398784
# 3894   283172   287941     3  148.754676  37.964259 -121.256914
# 3899   279791   287877     2  147.595662  34.193766 -116.254086
# 3836   234815   242261     1  146.988357  38.517011 -121.451331
# 3835   281059   285951     2  139.596303  38.517011 -121.451331
# 3904   272366   278533     2  138.470034  37.943493 -121.148128
# 3860   981892   983883     2  131.753812  33.017025 -117.273490
# 3911  1496807  1508644     2  131.408767  33.860069 -118.398784
# 3909   547186   555056     3  130.879876  37.734744 -122.214332
# 3910  1872491  1880546     3  129.919490  33.860069 -118.398784
# 3908   504182   509843     2  127.676582  37.734744 -122.214332
# 3907   459669   464491     1  124.564279  37.734744 -122.214332
# 3903   343911   350248     3  119.402770  37.943493 -121.148128
# 3902   236269   239553     1  118.745891  37.943493 -121.148128
# 3898   304513   313996     3  115.379972  34.193766 -116.254086
# 3890   229014   233284     1  112.642767  37.618393 -120.993368
# 3893   193530   196880     1  111.317190  37.964259 -121.256914
# 3889   292936   296738     3  109.980399  37.618393 -120.993368
# 3874   595273   603026     2  106.675006  38.580018 -121.462758
# 3859  1417585  1429899     3  103.728785  33.017025 -117.273490
# 3834   311619   315739     3   99.498945  38.517011 -121.451331

# %%
unique_cities = most_favorable_group['City']
unique_cities = unique_cities.unique()
unique_cities
# Out:
# array(['Manhattan Beach', 'Sacramento', 'Stockton', 'Encinitas',
#        'Joshua Tree', 'Modesto', 'Hermosa Beach', 'Garden Acres',
#        'Oakland'], dtype=object)

# %%
cities = most_favorable_group["City"].tolist()
marker_locations = most_favorable_group[['Lat', 'Lng']]

# %%
# Create a marker_layer using the poverty list to fill the info box and combine both maps together
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations,
    info_box_content=[f"Profitable: {cities}" for city in cities])
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Dependencies

import gmaps
import numpy as np
import pandas as pd
import requests
import time
from datetime import datetime
from scipy.stats import linregress
from matplotlib import pyplot as plt
from config_Laura import (gkey)

# %%
property_dataset = pd.read_csv('Resources_Laura/clean_property_value.csv')
property_dataset.head()
# Out:
#    RegionName RegionType StateName State       City                   Metro  \
# 0       95412        Zip        CA    CA  Annapolis              Santa Rosa
# 1       95412        Zip        CA    CA  Annapolis              Santa Rosa
# 2       95412        Zip        CA    CA  Annapolis              Santa Rosa
# 3       95017        Zip        CA    CA  Davenport  Santa Cruz-Watsonville
# 4       95017        Zip        CA    CA  Davenport  Santa Cruz-Watsonville
#
#           CountyName   1/31/14  2/28/21  3/31/21  Bdrm   % Change        Lat  \
# 0      Sonoma County  721046.0   526204   520369     1 -27.831373  38.713892
# 1      Sonoma County  730825.0   653418   645435     2 -11.684056  38.713892
# 2      Sonoma County  772083.0   935029   951287     3  23.210458  38.713892
# 3  Santa Cruz County  789701.0   609039   612187     1 -22.478634  37.091858
# 4  Santa Cruz County  669451.0   826864   847012     2  26.523375  37.091858
#
#           Lng
# 0 -123.326167
# 1 -123.326167
# 2 -123.326167
# 3 -122.231354
# 4 -122.231354

# %%
#sorting by % change and removing those that are negative, since we do not want to see those in the heatmap.
property_dataset = property_dataset.sort_values(by='% Change', ascending=False)
property_dataset = property_dataset.loc[property_dataset['% Change']>0]

# %%
# after cleaning, create back a dataframe for each of the houses with specific bedroom markets in case we want to separate
one_bedr = property_dataset.loc[property_dataset['Bdrm']==1]
two_bedr = property_dataset.loc[property_dataset['Bdrm']==2]
three_bedr = property_dataset.loc[property_dataset['Bdrm']==3]

# %%
min(three_bedr['% Change'])
# Out:
# 2.541375318248342

# %%
#CONFIGURE GMAPS
gmaps.configure(api_key=gkey)

# Store 'Lat' and 'Lng' into  locations 
locations = three_bedr[["Lat", "Lng"]].astype(float)

# humity to plot heat map
CAGR_percent = three_bedr["% Change"].astype(float)

# %%
# location Heatmap layer (change depending on which one you'd like to plot)
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=CAGR_percent, 
                                 dissipating=False, max_intensity=230,
                                 point_radius = 0.1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

one_bedr_zip = one_bedr['RegionName'].to_list()

rank_one = []
new_zipcode = []

for zipcode in one_bedr_zip:
    rank_one.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
one_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_one':rank_one})

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

two_bedr_zip = two_bedr['RegionName'].to_list()

rank_two = []
new_zipcode = []

for zipcode in two_bedr_zip:
    rank_two.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
two_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_two':rank_two})

# %%
# rank each of the top 20 cities (for each bedroom) and find the common denominator amongst all 3 types to rank them to identify cities that have increased their value in all 3 types of residential properties.
count = 1

three_bedr_zip = three_bedr['RegionName'].to_list()

rank_three = []
new_zipcode = []

for zipcode in three_bedr_zip:
    rank_three.append(count)
    new_zipcode.append(zipcode)
    count = count + 1
    
three_bedr_df = pd.DataFrame({'RegionName':new_zipcode,'rank_three':rank_three})

# %%
# final summary table to rank the zip codes with the highest increases in property values. We chose rank because if we do an average of % change of al three types, one high increase may impact the overall average.
ranking = pd.merge(one_bedr_df, two_bedr_df, on="RegionName")
ranking = pd.merge(ranking, three_bedr_df, on="RegionName")
ranking = ranking.dropna()
ranking.head()
# Out:
#    RegionName  rank_one  rank_two  rank_three
# 0       95822         1        24         331
# 1       95828         2       117         240
# 2       90266         3         1           3
# 3       95816         4       139           9
# 4       95818         5       408           8

# %%
#add rankings together, to see which zipcode has best % increase across all home types

sum_column = ranking["rank_one"] + ranking["rank_two"] + ranking["rank_three"]
ranking["rank_sum"] = sum_column
ranking = ranking.sort_values(by='rank_sum', ascending=True)
ranking.head(10)
# Out:
#     RegionName  rank_one  rank_two  rank_three  rank_sum
# 2        90266         3         1           3         7
# 9        92252        10        16          47        73
# 12       90254        13        44          28        85
# 75       95205        78         3          13        94
# 41       94621        43        52          25       120
# 50       95215        52        32          41       125
# 6        92007         7        42          81       130
# 19       95824        20        29          94       143
# 71       95351        74        13          59       146
# 3        95816         4       139           9       152

# %%
#find city that has best property increase value in all 3 house types
winner_value = int(ranking['RegionName'].head(1))
finder_value = property_dataset.loc[property_dataset['RegionName']==winner_value]
answer = finder_value['City']
answer = answer.drop_duplicates()


print('The zipcode with best ranking in terms of property value increase for one, two and three bedrooms is Sacramento''')
# Out:
# The zipcode with best ranking in terms of property value increase for one, two and three bedrooms is Sacramento

# %%
# dataset to plot the top 10 cities with highest ranking property increase for all 3 bedrooms
most_favorable = ranking.head(10)
most_favorable = most_favorable['RegionName'].to_list()
most_favorable_group = property_dataset.loc[property_dataset['RegionName'].isin(most_favorable)]
most_favorable_group
# Out:
#       RegionName RegionType StateName State             City  \
# 3470       95822        Zip        CA    CA       Sacramento
# 3631       95828        Zip        CA    CA           Florin
# 3922       90266        Zip        CA    CA  Manhattan Beach
# 3876       95816        Zip        CA    CA       Sacramento
# 3921       90266        Zip        CA    CA  Manhattan Beach
# 3473       95818        Zip        CA    CA       Sacramento
# 3749       95815        Zip        CA    CA       Sacramento
# 3920       90266        Zip        CA    CA  Manhattan Beach
# 3861       92007        Zip        CA    CA        Encinitas
# 3769       95358        Zip        CA    CA          Modesto
# 2880       90245        Zip        CA    CA       El Segundo
# 3900       92252        Zip        CA    CA      Joshua Tree
# 3472       95818        Zip        CA    CA       Sacramento
# 3875       95816        Zip        CA    CA       Sacramento
# 3899       92252        Zip        CA    CA      Joshua Tree
# 3469       95822        Zip        CA    CA       Sacramento
# 3768       95358        Zip        CA    CA          Modesto
# 3748       95815        Zip        CA    CA       Sacramento
# 3860       92007        Zip        CA    CA        Encinitas
# 3898       92252        Zip        CA    CA      Joshua Tree
# 3630       95828        Zip        CA    CA           Florin
# 3874       95816        Zip        CA    CA       Sacramento
# 3859       92007        Zip        CA    CA        Encinitas
# 3767       95358        Zip        CA    CA          Modesto
# 3747       95815        Zip        CA    CA       Sacramento
# 3629       95828        Zip        CA    CA           Florin
# 3471       95818        Zip        CA    CA       Sacramento
# 3468       95822        Zip        CA    CA       Sacramento
# 2879       90245        Zip        CA    CA       El Segundo
# 2878       90245        Zip        CA    CA       El Segundo
#
#                                     Metro             CountyName   1/31/14  \
# 3470  Sacramento--Roseville--Arden-Arcade      Sacramento County  115210.0
# 3631  Sacramento--Roseville--Arden-Arcade      Sacramento County   94743.0
# 3922       Los Angeles-Long Beach-Anaheim     Los Angeles County  804901.0
# 3876  Sacramento--Roseville--Arden-Arcade      Sacramento County  179658.0
# 3921       Los Angeles-Long Beach-Anaheim     Los Angeles County  802363.0
# 3473  Sacramento--Roseville--Arden-Arcade      Sacramento County  170088.0
# 3749  Sacramento--Roseville--Arden-Arcade      Sacramento County   93202.0
# 3920       Los Angeles-Long Beach-Anaheim     Los Angeles County  684856.0
# 3861                   San Diego-Carlsbad       San Diego County  499139.0
# 3769                              Modesto      Stanislaus County   97053.0
# 2880       Los Angeles-Long Beach-Anaheim     Los Angeles County  471111.0
# 3900     Riverside-San Bernardino-Ontario  San Bernardino County   96129.0
# 3472  Sacramento--Roseville--Arden-Arcade      Sacramento County  297671.0
# 3875  Sacramento--Roseville--Arden-Arcade      Sacramento County  299029.0
# 3899     Riverside-San Bernardino-Ontario  San Bernardino County  116269.0
# 3469  Sacramento--Roseville--Arden-Arcade      Sacramento County  160064.0
# 3768                              Modesto      Stanislaus County  111236.0
# 3748  Sacramento--Roseville--Arden-Arcade      Sacramento County  117765.0
# 3860                   San Diego-Carlsbad       San Diego County  424538.0
# 3898     Riverside-San Bernardino-Ontario  San Bernardino County  145787.0
# 3630  Sacramento--Roseville--Arden-Arcade      Sacramento County  141528.0
# 3874  Sacramento--Roseville--Arden-Arcade      Sacramento County  291775.0
# 3859                   San Diego-Carlsbad       San Diego County  701864.0
# 3767                              Modesto      Stanislaus County  180802.0
# 3747  Sacramento--Roseville--Arden-Arcade      Sacramento County  166006.0
# 3629  Sacramento--Roseville--Arden-Arcade      Sacramento County  199663.0
# 3471  Sacramento--Roseville--Arden-Arcade      Sacramento County  324577.0
# 3468  Sacramento--Roseville--Arden-Arcade      Sacramento County  213320.0
# 2879       Los Angeles-Long Beach-Anaheim     Los Angeles County  700625.0
# 2878       Los Angeles-Long Beach-Anaheim     Los Angeles County  934356.0
#
#       2/28/21  3/31/21  Bdrm    % Change        Lat         Lng
# 3470   390018   398346     1  245.756445  38.512871 -121.497029
# 3631   293825   301028     1  217.731125  38.492988 -121.388467
# 3922  2540611  2511376     1  212.010545  33.890837 -118.398784
# 3876   547554   551084     1  206.740585  38.580018 -121.462758
# 3921  2372472  2362929     3  194.496257  33.890837 -118.398784
# 3473   492207   500003     1  193.967240  38.560306 -121.497029
# 3749   266890   272679     1  192.567756  38.596316 -121.439904
# 3920  2005789  1993710     2  191.113752  33.890837 -118.398784
# 3861  1373708  1371843     1  174.841878  33.017025 -117.273490
# 3769   254763   260051     1  167.947410  37.610791 -121.102294
# 2880  1251776  1256144     1  166.634403  33.915007 -118.404626
# 3900   247008   255545     1  165.835492  34.193766 -116.254086
# 3472   764333   770494     3  158.840801  38.560306 -121.497029
# 3875   767138   771831     3  158.112424  38.580018 -121.462758
# 3899   279791   287877     2  147.595662  34.193766 -116.254086
# 3469   380118   386121     2  141.229133  38.512871 -121.497029
# 3768   261035   265712     2  138.872308  37.610791 -121.102294
# 3748   276295   280813     2  138.452002  38.596316 -121.439904
# 3860   981892   983883     2  131.753812  33.017025 -117.273490
# 3898   304513   313996     3  115.379972  34.193766 -116.254086
# 3630   296101   299419     2  111.561670  38.492988 -121.388467
# 3874   595273   603026     2  106.675006  38.580018 -121.462758
# 3859  1417585  1429899     3  103.728785  33.017025 -117.273490
# 3767   344982   350044     3   93.606265  37.610791 -121.102294
# 3747   316320   320005     3   92.767129  38.596316 -121.439904
# 3629   361729   366766     3   83.692522  38.492988 -121.388467
# 3471   572001   576220     2   77.529523  38.560306 -121.497029
# 3468   373155   378424     3   77.397337  38.512871 -121.497029
# 2879  1230891  1238354     2   76.749902  33.915007 -118.404626
# 2878  1521677  1526172     3   63.339455  33.915007 -118.404626

# %%
cities = most_favorable_group["City"].tolist()
marker_locations = most_favorable_group[['Lat', 'Lng']]

# %%
# Create a marker_layer using the poverty list to fill the info box and combine both maps together
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations,
    info_box_content=[f"Profitable: {cities}" for city in cities])
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
